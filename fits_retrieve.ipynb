# %%
import sys
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib
import numpy as np
from datetime import datetime, timedelta
import requests
import json
from pprint import pprint as pp

from astropy.io import fits
import astropy.io.fits as pyfits
import astropy.utils as autils
from astropy import units as u
from astropy.coordinates import SkyCoord
from astropy.wcs import WCS

# %%
natroot='https://astroarchive.noirlab.edu'
baseurl=f'{natroot}/api/sia'
print(f'This notebook demonstrates services rooted at: {baseurl}')

url = f'{baseurl}/vohdu?FORMAT=METADATA&format=json'
print(f'URL of service = {url}')
pd.DataFrame(requests.get(url).json()[1:])

adsurl = f'{natroot}/api/adv_search'

all_cats = requests.get(f'{adsurl}/cat_lists/?format=json').json()
# Out:
# This notebook demonstrates services rooted at: https://astroarchive.noirlab.edu/api/sia
# URL of service = https://astroarchive.noirlab.edu/api/sia/vohdu?FORMAT=METADATA&format=json

# %%
#try:
#    c = name_resolve.get_icrs_coordinates('NGC 2158')
#except:
#    print('name resolve failed')
#    coord_str="01 41 59.0 +32 03 52.8"
#    c=SkyCoord(coord_str,unit=(u.hourangle, u.deg))

#coord_str="01 41 59.0 +32 03 52.8"
#c=SkyCoord(coord_str,unit=(u.hourangle, u.deg))

#ra = c.ra.value # in degrees
#dec = c.dec.value # in degrees
#size = 5 # search radius in degrees


jj = {
    "outfields" : [
        "telescope",
        "md5sum",
        "ra_min",  # "ra" is a "range_field" in Postgres, access either part of range
        "archive_filename",
        "instrument",
        "proc_type",
        "ifilter",
        "obs_type",
        "release_date",
        "proposal",
        "caldat",
        "EXPTIME",
        "AIRMASS",
        "OBJECT",
        "SEQID"
    ],
    "search" : [
        ["instrument", "newfirm"],
        ["proc_type", "instcal"],
        ["exposure",0,10]
    ]
}

adsurl = f'{natroot}/api/adv_search'

print(f'Using API url: {adsurl}')

result_limit = 100000
sia_results = pd.DataFrame(requests.post(f'{adsurl}/find/?limit={result_limit}',json=jj).json()[1:])
# Out:
# Using API url: https://astroarchive.noirlab.edu/api/adv_search

# %%
plt.figure()
plt.subplot(2,2,1)
sia_results[(sia_results['telescope'] == 'kp4m')]['ifilter'].value_counts()[:10].plot(kind='bar')
plt.title('Short Exp. Filter Type at KP')

plt.subplot(2,2,2)
sia_results[(sia_results['telescope'] == 'ct4m')]['ifilter'].value_counts()[:10].plot(kind='bar')
plt.title('Short Exp. Filter Type at CT')

plt.subplot(2,2,3)
sia_results[(sia_results['telescope'] == 'kp4m')]['EXPTIME'].value_counts().loc[:10].plot(kind='bar')
plt.title('Exp. Time at KP')

plt.subplot(2,2,4)
sia_results[(sia_results['telescope'] == 'ct4m')]['EXPTIME'].value_counts().loc[:10].plot(kind='bar')
plt.title('Exp Time at CT')
plt.gcf().tight_layout()

# %%
requests.get(f'{adsurl}/aux_file_fields/newfirm/instcal/').json()
# Out:
# [{'Field': 'AIRMASS', 'Type': 'str', 'Desc': 'Airmass'},
#  {'Field': 'ALT', 'Type': 'str', 'Desc': 'Telescope altitude'},
#  {'Field': 'ASTRMCAT',
#   'Type': 'str',
#   'Desc': 'Catalog used for astrometric calibration'},
#  {'Field': 'AZ', 'Type': 'str', 'Desc': 'Telescope azimuth'},
#  {'Field': 'BUNIT', 'Type': 'str', 'Desc': 'photoelectrons per second'},
#  {'Field': 'CENTDEC', 'Type': 'str', 'Desc': '[deg] DEC center of exposure'},
#  {'Field': 'CENTRA', 'Type': 'str', 'Desc': '[deg] RA center of exposure'},
#  {'Field': 'CORN1DEC', 'Type': 'str', 'Desc': '[deg] DEC corner of exposure'},
#  {'Field': 'CORN1RA', 'Type': 'str', 'Desc': '[deg] RA corner of exposure'},
#  {'Field': 'CORN2DEC', 'Type': 'str', 'Desc': '[deg] DEC corner of exposure'},
#  {'Field': 'CORN2RA', 'Type': 'str', 'Desc': '[deg] RA corner of exposure'},
#  {'Field': 'CORN3DEC', 'Type': 'str', 'Desc': '[deg] DEC corner of exposure'},
#  {'Field': 'CORN3RA', 'Type': 'str', 'Desc': '[deg] RA corner of exposure'},
#  {'Field': 'CORN4DEC', 'Type': 'str', 'Desc': '[deg] DEC corner of exposure'},
#  {'Field': 'CORN4RA', 'Type': 'str', 'Desc': '[deg] RA corner of exposure'},
#  {'Field': 'DARKINFO', 'Type': 'str', 'Desc': ''},
#  {'Field': 'DATE', 'Type': 'str', 'Desc': 'Date FITS file was generated'},
#  {'Field': 'DATE-OBS',
#   'Type': 'str',
#   'Desc': 'Date of observation start (UTC approximate)'},
#  {'Field': 'DEC', 'Type': 'str', 'Desc': 'DEC of observation (deg)'},
#  {'Field': 'DECDIFF', 'Type': 'str', 'Desc': '[arcsec] Dec diff'},
#  {'Field': 'DECINDEX', 'Type': 'str', 'Desc': '[arcsec] Dec index'},
#  {'Field': 'DECINST', 'Type': 'str', 'Desc': '[arcsec] Dec instrument center'},
#  {'Field': 'DECOFF', 'Type': 'str', 'Desc': '[arcsec] Dec offset'},
#  {'Field': 'DECZERO', 'Type': 'str', 'Desc': '[arcsec] Dec zero'},
#  {'Field': 'DIGAVGS', 'Type': 'str', 'Desc': 'Digital Averages'},
#  {'Field': 'DOMEAZ', 'Type': 'str', 'Desc': 'Dome azimuth'},
#  {'Field': 'DOMEERR',
#   'Type': 'str',
#   'Desc': '[deg] Dome error as distance from target'},
#  {'Field': 'DPTHADU', 'Type': 'str', 'Desc': ''},
#  {'Field': 'DQMFOR', 'Type': 'str', 'Desc': ''},
#  {'Field': 'DTACCOUN', 'Type': 'str', 'Desc': 'observing account name'},
#  {'Field': 'DTACQNAM', 'Type': 'str', 'Desc': ''},
#  {'Field': 'DTACQUIS',
#   'Type': 'str',
#   'Desc': 'host name of data acquisition computer'},
#  {'Field': 'DTCALDAT', 'Type': 'str', 'Desc': ''},
#  {'Field': 'DTCOPYRI', 'Type': 'str', 'Desc': 'copyright holder of data'},
#  {'Field': 'DTINSTRU', 'Type': 'str', 'Desc': ''},
#  {'Field': 'DTNSANAM', 'Type': 'str', 'Desc': ''},
#  {'Field': 'DTOBSERV', 'Type': 'str', 'Desc': 'scheduling institution'},
#  {'Field': 'DTPI', 'Type': 'str', 'Desc': ''},
#  {'Field': 'DTPIAFFL', 'Type': 'str', 'Desc': 'PI affiliation'},
#  {'Field': 'DTPROPID',
#   'Type': 'str',
#   'Desc': 'Proposal ID validated by Archive'},
#  {'Field': 'DT_RTNAM', 'Type': 'str', 'Desc': 'NSA root name'},
#  {'Field': 'DTSITE',
#   'Type': 'str',
#   'Desc': 'Telescope / observatory locale from which original raw data was taken'},
#  {'Field': 'DTSTATUS', 'Type': 'str', 'Desc': 'data transport status'},
#  {'Field': 'DTTELESC', 'Type': 'str', 'Desc': ''},
#  {'Field': 'DTTITL_1', 'Type': 'str', 'Desc': ''},
#  {'Field': 'DTTITL_2', 'Type': 'str', 'Desc': ''},
#  {'Field': 'DTTITLE', 'Type': 'str', 'Desc': ''},
#  {'Field': 'DTUTC', 'Type': 'str', 'Desc': 'post exposure UTC epoch from DTS'},
#  {'Field': 'EFFTIME', 'Type': 'str', 'Desc': '[s] Effective exposure time'},
#  {'Field': 'EXPCOADD', 'Type': 'str', 'Desc': '[s] Single coadd exp time'},
#  {'Field': 'EXPID', 'Type': 'str', 'Desc': 'exposure ID'},
#  {'Field': 'EXPTIME', 'Type': 'str', 'Desc': 'Exposure time in secs'},
#  {'Field': 'F8FOCUS', 'Type': 'str', 'Desc': ''},
#  {'Field': 'FILENAME', 'Type': 'str', 'Desc': 'Original host filename'},
#  {'Field': 'FILTER', 'Type': 'str', 'Desc': 'Filter name(s)'},
#  {'Field': 'FILTID', 'Type': 'str', 'Desc': 'Unique filter identification'},
#  {'Field': 'FIXPIX', 'Type': 'str', 'Desc': ''},
#  {'Field': 'FSAMPLE', 'Type': 'str', 'Desc': 'number of fowler samples'},
#  {'Field': 'FSOBJECT', 'Type': 'str', 'Desc': ''},
#  {'Field': 'GAIN',
#   'Type': 'str',
#   'Desc': 'gain expected for amp 111 (e-/ADU)'},
#  {'Field': 'HA', 'Type': 'str', 'Desc': 'hour angle (H:M:S)'},
#  {'Field': 'INSTRUME', 'Type': 'str', 'Desc': 'Instrument name'},
#  {'Field': 'IRAF-TLM', 'Type': 'str', 'Desc': 'Time of last modification'},
#  {'Field': 'LAMPSTAT', 'Type': 'str', 'Desc': 'Lamp status'},
#  {'Field': 'MAGZERO', 'Type': 'str', 'Desc': ''},
#  {'Field': 'MAGZERR', 'Type': 'str', 'Desc': ''},
#  {'Field': 'MAGZNAV', 'Type': 'str', 'Desc': ''},
#  {'Field': 'MAGZNAV1', 'Type': 'str', 'Desc': ''},
#  {'Field': 'MAGZREF', 'Type': 'str', 'Desc': ''},
#  {'Field': 'MAGZSIG', 'Type': 'str', 'Desc': ''},
#  {'Field': 'MIMETYPE', 'Type': 'str', 'Desc': 'Mimetype of this data file'},
#  {'Field': 'MJDEND', 'Type': 'str', 'Desc': 'MJD of observation end'},
#  {'Field': 'MJD-OBS', 'Type': 'str', 'Desc': 'MJD of observation start'},
#  {'Field': 'MJDSTART', 'Type': 'str', 'Desc': 'MJD of observation start'},
#  {'Field': 'MOSSIZE', 'Type': 'str', 'Desc': 'Mosaic detector size'},
#  {'Field': 'NCOADD', 'Type': 'str', 'Desc': 'Number of coadds'},
#  {'Field': 'NDETS', 'Type': 'str', 'Desc': 'Number of detectors in mosaic'},
#  {'Field': 'NFC1FILT', 'Type': 'str', 'Desc': 'Camera 1 filter'},
#  {'Field': 'NFC1GDR', 'Type': 'str', 'Desc': 'Camera 1 guider mode'},
#  {'Field': 'NFC1POS',
#   'Type': 'str',
#   'Desc': 'Camera 1 target (HH:MM:SS.SS DD:MM'},
#  {'Field': 'NFC2FILT', 'Type': 'str', 'Desc': 'Camera 2 filter'},
#  {'Field': 'NFC2GDR', 'Type': 'str', 'Desc': 'Camera 2 guider mode'},
#  {'Field': 'NFC2POS',
#   'Type': 'str',
#   'Desc': 'Camera 2 target (HH:MM:SS.SS DD:MM'},
#  {'Field': 'NFDETTMP',
#   'Type': 'str',
#   'Desc': '[K] detector array temp measured'},
#  {'Field': 'NFECPOS',
#   'Type': 'str',
#   'Desc': 'detected position (open|close|between)'},
#  {'Field': 'NFFILPOS', 'Type': 'str', 'Desc': 'Filter detected position name'},
#  {'Field': 'NFFW1POS',
#   'Type': 'str',
#   'Desc': 'Wheel 1 actual position (0|1|2|3|4|5|6|7|8)'},
#  {'Field': 'NFFW2POS',
#   'Type': 'str',
#   'Desc': 'Wheel 2 actual position (0|1|2|3|4|5|6|7|8)'},
#  {'Field': 'NFOSSTMP', 'Type': 'str', 'Desc': '[K] oss temp measured'},
#  {'Field': 'NOCAOE', 'Type': 'str', 'Desc': ''},
#  {'Field': 'NOCBIAS', 'Type': 'str', 'Desc': 'Bias voltage applied'},
#  {'Field': 'NOCCOADD', 'Type': 'str', 'Desc': 'Number of coadds requested'},
#  {'Field': 'NOCDDOF', 'Type': 'str', 'Desc': '[arcsec] Dither Dec offset'},
#  {'Field': 'NOCDGAVG',
#   'Type': 'str',
#   'Desc': 'Number of digital averages requested'},
#  {'Field': 'NOCDHS', 'Type': 'str', 'Desc': 'DHS script name'},
#  {'Field': 'NOCDITER', 'Type': 'str', 'Desc': 'Dither iteration count'},
#  {'Field': 'NOCDPAT', 'Type': 'str', 'Desc': 'Dither pattern'},
#  {'Field': 'NOCDPOS', 'Type': 'str', 'Desc': 'Dither position'},
#  {'Field': 'NOCDREP', 'Type': 'str', 'Desc': 'Dither repetition count'},
#  {'Field': 'NOCDROF', 'Type': 'str', 'Desc': '[arcsec] Dither RA offset'},
#  {'Field': 'NOCFOCUS', 'Type': 'str', 'Desc': '[um] ntcs_focus value'},
#  {'Field': 'NOCFSMPL', 'Type': 'str', 'Desc': 'Number of fSamples requested'},
#  {'Field': 'NOCFSN', 'Type': 'str', 'Desc': 'Filter serial number'},
#  {'Field': 'NOCGID', 'Type': 'str', 'Desc': ''},
#  {'Field': 'NOCID', 'Type': 'str', 'Desc': 'NEWFIRM ID'},
#  {'Field': 'NOCLAMP',
#   'Type': 'str',
#   'Desc': 'Dome flat lamp status (on|off|unknown)'},
#  {'Field': 'NOCMDOF', 'Type': 'str', 'Desc': '[arcsec] Map Dec offset'},
#  {'Field': 'NOCMITER', 'Type': 'str', 'Desc': 'Map iteration count'},
#  {'Field': 'NOCMPAT', 'Type': 'str', 'Desc': 'Map pattern'},
#  {'Field': 'NOCMPOS', 'Type': 'str', 'Desc': 'Map position'},
#  {'Field': 'NOCMREP', 'Type': 'str', 'Desc': 'Map repetition count'},
#  {'Field': 'NOCMROF', 'Type': 'str', 'Desc': '[arcsec] Map RA offset'},
#  {'Field': 'NOCNAME', 'Type': 'str', 'Desc': ''},
#  {'Field': 'NOCNO',
#   'Type': 'str',
#   'Desc': 'observation number in this sequence'},
#  {'Field': 'NOCNPOS',
#   'Type': 'str',
#   'Desc': 'observation number in requested number'},
#  {'Field': 'NOCNUM', 'Type': 'str', 'Desc': 'observation number request'},
#  {'Field': 'NOCOAE', 'Type': 'str', 'Desc': 'OAs E-mail Address'},
#  {'Field': 'NOCODEC', 'Type': 'str', 'Desc': '[arcsec] Dec offset'},
#  {'Field': 'NOCORA', 'Type': 'str', 'Desc': '[arcsec] RA offset'},
#  {'Field': 'NOCPIE', 'Type': 'str', 'Desc': 'PIs E-mail Address'},
#  {'Field': 'NOCPOST', 'Type': 'str', 'Desc': 'ntcs_moveto ra dec epoch'},
#  {'Field': 'NOCRSD', 'Type': 'str', 'Desc': ''},
#  {'Field': 'NOCSCR', 'Type': 'str', 'Desc': 'NOHS script run'},
#  {'Field': 'NOCSKY', 'Type': 'str', 'Desc': 'sky offset modulus'},
#  {'Field': 'NOCSYS', 'Type': 'str', 'Desc': 'system ID'},
#  {'Field': 'NOCTIM', 'Type': 'str', 'Desc': '[s] Requested integration time'},
#  {'Field': 'NOCTOT',
#   'Type': 'str',
#   'Desc': 'Total number of observations in set'},
#  {'Field': 'NOCTYP', 'Type': 'str', 'Desc': 'Observation type'},
#  {'Field': 'NOCUTC', 'Type': 'str', 'Desc': ''},
#  {'Field': 'NOHS', 'Type': 'str', 'Desc': ''},
#  {'Field': 'OBJDEC', 'Type': 'str', 'Desc': '[deg] DEC of target'},
#  {'Field': 'OBJECT', 'Type': 'str', 'Desc': 'Name of the object observed'},
#  {'Field': 'OBJEPOCH',
#   'Type': 'str',
#   'Desc': '[yr] Epoch of target coordinates'},
#  {'Field': 'OBJRA', 'Type': 'str', 'Desc': '[h] RA of target'},
#  {'Field': 'OBS-ELEV', 'Type': 'str', 'Desc': '[km] Observatory elevation'},
#  {'Field': 'OBSERVAT', 'Type': 'str', 'Desc': 'Observatory'},
#  {'Field': 'OBSERVER', 'Type': 'str', 'Desc': 'Observer(s)'},
#  {'Field': 'OBSID', 'Type': 'str', 'Desc': 'Observation ID'},
#  {'Field': 'OBS-LAT', 'Type': 'str', 'Desc': '[deg] Observatory latitude'},
#  {'Field': 'OBS-LONG', 'Type': 'str', 'Desc': '[deg] Observatory longitude'},
#  {'Field': 'OBSTYPE',
#   'Type': 'str',
#   'Desc': 'Type of target observed (e.g. object, dark, dome flat...)'},
#  {'Field': 'ODATEOBS', 'Type': 'str', 'Desc': ''},
#  {'Field': 'ORIGIN', 'Type': 'str', 'Desc': 'FITS file originator'},
#  {'Field': 'PHOTAPD',
#   'Type': 'str',
#   'Desc': '[pix] Aperture diameter for MAGZERO'},
#  {'Field': 'PHOTBW', 'Type': 'str', 'Desc': '[nm] Filter wavelength FWHM'},
#  {'Field': 'PHOTCLAM', 'Type': 'str', 'Desc': '[nm] Filter wavelenght width'},
#  {'Field': 'PHOTDPTH',
#   'Type': 'str',
#   'Desc': '[mag] 5 sig point source photometric depth'},
#  {'Field': 'PHOTFWHM', 'Type': 'str', 'Desc': '[nm] Filter wavelength FWHM'},
#  {'Field': 'PHOTINDX', 'Type': 'str', 'Desc': ''},
#  {'Field': 'PIPELINE', 'Type': 'str', 'Desc': 'Name of calibration pipeline'},
#  {'Field': 'PLARVER', 'Type': 'str', 'Desc': 'PL NSA archive version'},
#  {'Field': 'PLDNAME', 'Type': 'str', 'Desc': 'PL Dataset'},
#  {'Field': 'PLDSID', 'Type': 'str', 'Desc': 'PL NSA name'},
#  {'Field': 'PLFNAME', 'Type': 'str', 'Desc': 'PL Filename'},
#  {'Field': 'PLOFNAME', 'Type': 'str', 'Desc': 'Original file name'},
#  {'Field': 'PLPROCID', 'Type': 'str', 'Desc': 'PL Processing ID'},
#  {'Field': 'PLPROPID', 'Type': 'str', 'Desc': 'PL Proposal ID'},
#  {'Field': 'PLQNAME', 'Type': 'str', 'Desc': 'PL Dataset'},
#  {'Field': 'PLQUEUE', 'Type': 'str', 'Desc': 'PL Queue'},
#  {'Field': 'PLVER', 'Type': 'str', 'Desc': 'Pipeline version'},
#  {'Field': 'PROCTYPE',
#   'Type': 'str',
#   'Desc': 'Processing Type ( Raw | Instcal | Resampled | Stack | MasterCal )'},
#  {'Field': 'PRODTYPE',
#   'Type': 'str',
#   'Desc': 'Product data description ( image | mask | expmap )'},
#  {'Field': 'PROPID', 'Type': 'str', 'Desc': 'Proposal identification'},
#  {'Field': 'PROPOSER', 'Type': 'str', 'Desc': 'Proposer(s)'},
#  {'Field': 'QUALINFO', 'Type': 'str', 'Desc': ''},
#  {'Field': 'RA', 'Type': 'str', 'Desc': 'RA of observation (hr)'},
#  {'Field': 'RADECSYS', 'Type': 'str', 'Desc': 'Default coordinate system'},
#  {'Field': 'RADIFF', 'Type': 'str', 'Desc': '[arcsec] RA diff'},
#  {'Field': 'RAINDEX', 'Type': 'str', 'Desc': '[arcsec] RA index'},
#  {'Field': 'RAINST', 'Type': 'str', 'Desc': '[arcsec] RA instrument center'},
#  {'Field': 'RAOFF', 'Type': 'str', 'Desc': '[arcsec] RA offset'},
#  {'Field': 'RAWFILE', 'Type': 'str', 'Desc': 'Original raw file'},
#  {'Field': 'RAZERO', 'Type': 'str', 'Desc': '[arcsec] RA zero'},
#  {'Field': 'RECNO',
#   'Type': 'str',
#   'Desc': 'NOAO Science Archive sequence number'},
#  {'Field': 'RMCALDAT', 'Type': 'str', 'Desc': ''},
#  {'Field': 'RMCOUNT', 'Type': 'str', 'Desc': 'remediation counter'},
#  {'Field': 'RMPROPID', 'Type': 'str', 'Desc': ''},
#  {'Field': 'RSPGRP', 'Type': 'str', 'Desc': ''},
#  {'Field': 'RSPTGRP', 'Type': 'str', 'Desc': ''},
#  {'Field': 'SATURATE', 'Type': 'str', 'Desc': 'Maximum good data value (ADU)'},
#  {'Field': 'SB_ACCOU', 'Type': 'str', 'Desc': 'iSTB client user account'},
#  {'Field': 'SB_DIR1', 'Type': 'str', 'Desc': 'level 1 directory in NSA DS'},
#  {'Field': 'SB_DIR2', 'Type': 'str', 'Desc': 'level 2 directory in NSA DS'},
#  {'Field': 'SB_DIR3', 'Type': 'str', 'Desc': 'level 3 directory in NSA DS'},
#  {'Field': 'SB_HOST', 'Type': 'str', 'Desc': 'iSTB client host'},
#  {'Field': 'SB_ID', 'Type': 'str', 'Desc': 'unique iSTB identifier'},
#  {'Field': 'SB_LOCAL', 'Type': 'str', 'Desc': 'locale of iSTB daemon'},
#  {'Field': 'SB_NAME', 'Type': 'str', 'Desc': 'name assigned by iSTB'},
#  {'Field': 'SB_RECNO', 'Type': 'str', 'Desc': 'iSTB sequence number'},
#  {'Field': 'SB_RTNAM', 'Type': 'str', 'Desc': 'NSA root name'},
#  {'Field': 'SB_SITE', 'Type': 'str', 'Desc': 'iSTB host site'},
#  {'Field': 'SEEING', 'Type': 'str', 'Desc': ''},
#  {'Field': 'SEEING1', 'Type': 'str', 'Desc': '[arcsec] seeing'},
#  {'Field': 'SEEINGP', 'Type': 'str', 'Desc': ''},
#  {'Field': 'SEQID', 'Type': 'str', 'Desc': 'Sequence ID'},
#  {'Field': 'SEQNUM', 'Type': 'str', 'Desc': 'Sequence Number'},
#  {'Field': 'SIGMEAN', 'Type': 'str', 'Desc': ''},
#  {'Field': 'SKYBG', 'Type': 'str', 'Desc': ''},
#  {'Field': 'SKYMAG', 'Type': 'str', 'Desc': '[mag/arcsec^2] sky magnitude'},
#  {'Field': 'SKYMAG1', 'Type': 'str', 'Desc': '[mag/arcsec^2] sky brightness'},
#  {'Field': 'SKYNOISE', 'Type': 'str', 'Desc': ''},
#  {'Field': 'ST', 'Type': 'str', 'Desc': 'Local Sidereal Time [hhmmss.s]'},
#  {'Field': 'TCPGDR', 'Type': 'str', 'Desc': 'Guider status (on|off|lock)'},
#  {'Field': 'TCPTRACK', 'Type': 'str', 'Desc': 'telescope tracking status'},
#  {'Field': 'TELDEC', 'Type': 'str', 'Desc': 'DEC of telescope (deg)'},
#  {'Field': 'TELEQUIN', 'Type': 'str', 'Desc': 'Equinox of tel coords'},
#  {'Field': 'TELESCOP', 'Type': 'str', 'Desc': 'Telescope'},
#  {'Field': 'TELFOCUS', 'Type': 'str', 'Desc': 'Telescope focus'},
#  {'Field': 'TELOP',
#   'Type': 'str',
#   'Desc': 'Telescope operator or observing assistants(s)'},
#  {'Field': 'TELRA', 'Type': 'str', 'Desc': 'RA of telescope (hr)'},
#  {'Field': 'TELRADEC', 'Type': 'str', 'Desc': 'Telescope coordinate system'},
#  {'Field': 'TIME-OBS', 'Type': 'str', 'Desc': 'Time of observation start'},
#  {'Field': 'TIMESYS', 'Type': 'str', 'Desc': 'Time system'},
#  {'Field': 'TITLE', 'Type': 'str', 'Desc': ''},
#  {'Field': 'WAT1_001', 'Type': 'str', 'Desc': ''},
#  {'Field': 'WAT1_002', 'Type': 'str', 'Desc': ''},
#  {'Field': 'WAT2_001', 'Type': 'str', 'Desc': ''},
#  {'Field': 'WAT2_002', 'Type': 'str', 'Desc': ''},
#  {'Field': 'WCSAXES', 'Type': 'str', 'Desc': 'Number of WCS axes'},
#  {'Field': 'WCSCAL', 'Type': 'str', 'Desc': ''},
#  {'Field': 'WCSXRMS', 'Type': 'str', 'Desc': ''},
#  {'Field': 'WCSYRMS', 'Type': 'str', 'Desc': ''},
#  {'Field': 'ZD', 'Type': 'str', 'Desc': 'Zenith distance'}]

# %%
jj = {
    "outfields" : [
        "telescope",
        "md5sum",
        "ra_min",  # "ra" is a "range_field" in Postgres, access either part of range
        "archive_filename",
        "original_filename",
        "instrument",
        "proc_type",
        "ifilter",
        "obs_type",
        "release_date",
        "proposal",
        "caldat",
        "RAWFILE",
        "EXPTIME",
        "AIRMASS",
        "OBJECT",
        "SEQID",
        "url"
    ],
    "search" : [
        ["instrument", "newfirm"],
        ["proc_type", "instcal"],
        ["ifilter","KXs"],
        ["exposure",10,10]
        #["telescope","kp4m"],
        #["ra_min",ra-0.05,ra+0.05]
    ]
}

adsurl = f'{natroot}/api/adv_search'

print(f'Using API url: {adsurl}')

result_limit = 100000
sia_results2 = pd.DataFrame(requests.post(f'{adsurl}/find/?limit={result_limit}',json=jj).json()[1:])
# Out:
# Using API url: https://astroarchive.noirlab.edu/api/adv_search

# %%
plt.figure()
plt.subplot(1,2,1)
sia_results2[(sia_results2['telescope'] == 'kp4m')]['EXPTIME'].value_counts().loc[:10].plot(kind='bar')
plt.title('KXs Exp Time at KP')

plt.subplot(1,2,2)
sia_results2[(sia_results2['telescope'] == 'ct4m')]['EXPTIME'].value_counts().loc[:10].plot(kind='bar')
plt.title('KXs Exp Time at CT')

plt.gcf().tight_layout()

# %%
sia_results3 = sia_results2[~sia_results2.OBJECT.str.contains('Mask', regex=True,na=False)]
sia_results3 = sia_results3[~sia_results3.OBJECT.str.contains('defocus', regex=True,na=False)]


sia_results3['datetime_rel'] = pd.to_datetime(sia_results3.release_date)
sia_results3 = sia_results3[sia_results3.datetime_rel < datetime.now()]

sia_results3 = sia_results3.head(10)
sia_results3 = sia_results3.reset_index()

sia_results3 = sia_results3.assign(ra_center=str(0),
                                   dec_center=str(0),
                                   coord_sys=str(0),
                                   obs_lat=str(0),
                                   obs_long=str(0),
                                   tel_az=str(0),
                                   astro_cal_cat=str(0))

for index, row in sia_results3.iterrows():
    hdu = fits.open(row['url'])
    hdr = hdu[0].header
    print(hdr['RAWFILE'])

    sia_results3['ra_center'].at[index] = hdr['CENTRA']
    sia_results3['dec_center'].at[index] = hdr['CENTDEC']
    sia_results3['coord_sys'].at[index] = hdr['RADECSYS']
    sia_results3['obs_lat'].at[index] = hdr['OBS-LAT']
    sia_results3['obs_long'].at[index] = hdr['OBS-LONG']
    sia_results3['tel_az'].at[index] = hdr['AZ']
    sia_results3['astro_cal_cat'].at[index] = hdr['ASTRMCAT']
# Out:
# n4_249523.fits
# n4305565.fits
# n6307818.fits
# n5_231441.fits
# n5_231442.fits
# n5_231443.fits
# n5_231444.fits
# 20140319_279942.fits
# n2_247765.fits
# n2_247766.fits

# %%
from astroquery.simbad import Simbad


c = SkyCoord(sia_results3['ra_center'].iloc[1]*u.deg,sia_results3['dec_center'].iloc[1]*u.deg,frame=sia_results3['coord_sys'].iloc[1].lower())
r = 28 * u.arcminute # 28 arcminutes is the FOV of the NEWFIRM imager (both horizontal and vertical)

adql = rf"""SELECT main_id, ra, dec, otype, flux, filter, bibcode AS flux_reference 
FROM flux JOIN basic ON oidref = oid
WHERE main_id LIKE '2MASS%'
AND CONTAINS(POINT('ICRS', basic.ra, basic.dec), CIRCLE('ICRS', {c.ra.deg}, {c.dec.deg} , {r.to(u.degree).to_value()})) = 1
"""

tap_results = Simbad.query_tap(adql)

# %%
from astropy.wcs import WCS

hdu = fits.open(sia_results3.iloc[1]['url'])
hdr = hdu[0].header

raw_file_name = hdr['SB_RTNAM']

# %% [markdown]
# Next up is extracting the name of the raw image used to create the instcal. Once the raw file is recovered, I can run my pipeline on it to see how it compares with the instcal.

# %%
hdu = fits.open(sia_results3['url'][1])
hdr = hdu[0].header
this_seqid = hdr['SEQID']
this_instr = hdr['INSTRUME']
this_propid = hdr['PROPID']
this_caldat = hdr['DTCALDAT']
this_filter = hdr['FILTER']
this_rawfile = hdr['RAWFILE']
this_filename = hdr.cards['FILENAME'][1]

jj = {
    "outfields" : [
        "telescope",
        "md5sum",
        "ra_min",  # "ra" is a "range_field" in Postgres, access either part of range
        "archive_filename",
        "original_filename",
        "instrument",
        "proc_type",
        "ifilter",
        "obs_type",
        "release_date",
        "proposal",
        "caldat",
        "DATE-OBS",
        "EXPTIME",
        "AIRMASS",
        "OBJECT",
        "SEQID",
        "url"
    ],
    "search" : [
        ["instrument", this_instr],
        ["proc_type","raw"],
        #["proposal",this_propid],
        ["original_filename",this_rawfile,'contains']
    ]
        
}

result_limit = 10

sia_raw_df = pd.DataFrame(requests.post(f'{adsurl}/find/?limit={result_limit}',json=jj).json()[1:])
# Out:
# Using API url: https://astroarchive.noirlab.edu/api/adv_search

# %%
hdul = fits.open(sia_raw_df['url'][0])
element = 2
hdr = hdul[element].header
w = WCS(hdr)

fits_image = hdul[element].data
plt.imshow(fits_image)
plt.gca().invert_yaxis()

# %% [markdown]
# With the raw data and its coordinate system ready, now it's time to bring in the expected cal star locations

# %%
from dl import queryClient as qc

hdr = hdul[element].header
ra = hdr['RA'] # in degrees
dec = hdr['DEC'] # in degrees

frm = hdul[0].header['RADECSYS'].lower()

c = SkyCoord(ra,dec,frame=frm,unit=(u.hourangle,u.deg))

fov = 28 * u.arcminute * 2

sql = '''SELECT ra, dec, gmag 
            FROM nsc_dr2.object 
            WHERE Q3C_RADIAL_QUERY(ra,dec,{0},{1},{2})
            AND gerr < 0.1 AND gmag < 22
'''.format(c.ra.value, c.dec.value, (fov.to(u.deg)).value)
stars_df = qc.query(sql=sql, fmt='pandas')

# %%
fig = plt.figure(figsize=(10,10))
ax = fig.add_subplot(1, 1, 1, projection=w)
ax1 = ax.imshow(fits_image, cmap='gray')#, vmin=fits_image.min(), vmax=fits_image.min()+(fits_image.max()-fits_image.min())/100.)
ax2 = ax.scatter(stars_df['ra'], stars_df['dec'], transform=ax.get_transform('icrs'), s=1000./(stars_df['gmag']-12), edgecolor='green', facecolor='none', linewidths=3)
plt.xlim(ax1.get_extent()[0], ax1.get_extent()[1])
plt.ylim(ax1.get_extent()[2], ax1.get_extent()[3])
plt.show()

# %%
prior_day = str((pd.to_datetime(this_caldat)-pd.to_timedelta(1,'days')).date())


jj = {
    "outfields" : [
        "telescope",
        "md5sum",
        "ra_min",  # "ra" is a "range_field" in Postgres, access either part of range
        "archive_filename",
        "original_filename",
        "instrument",
        "proc_type",
        "prod_type",
        "ifilter",
        "obs_type",
        "release_date",
        "proposal",
        "caldat",
        "DATE-OBS",
        "EXPTIME",
        "AIRMASS",
        "OBJECT",
        "SEQID",
        "url"
    ],
    "search" : [
        ["instrument", this_instr],
        ["proc_type","raw"],
        ["PROPID",this_propid],
        ["prod_type","image"],
        ["obs_type","dark","flat","dome flat"],
        ["caldat",prior_day,this_caldat]
    ]
        
}

result_limit = 1000

sia_cal_df = pd.DataFrame(requests.post(f'{adsurl}/find/?limit={result_limit}',json=jj).json()[1:])

# %%
sia_cal_df['start_time'] = pd.to_datetime(sia_cal_df['DATE-OBS'])
sia_cal_df['dTime'] = pd.to_numeric(sia_cal_df['start_time'] - pd.to_datetime(hdr['DATE-OBS']))

nearest_darks = sia_cal_df[sia_results2.OBJECT.str.contains('Mask', regex=True,na=False)]
# Out:
# C:\Users\flann\AppData\Local\Temp\ipykernel_2288\2137272157.py:4: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   nearest_darks = sia_cal_df[sia_results2.OBJECT.str.contains('Mask', regex=True,na=False)]

# %%
jj = {
    "outfields" : [
        "telescope",
        "md5sum",
        "ra_min",  # "ra" is a "range_field" in Postgres, access either part of range
        "archive_filename",
        "original_filename",
        "instrument",
        "proc_type",
        "prod_type",
        "ifilter",
        "obs_type",
        "release_date",
        "proposal",
        "caldat",
        "DATE-OBS",
        "EXPTIME",
        "AIRMASS",
        "OBJECT",
        "SEQID",
        "url"
    ],
    "search" : [
        ["instrument", this_instr],
        ["proc_type","instcal"],
        ["PROPID",this_propid],
        ["SEQID",this_seqid],
        ["prod_type","dqmask"],
        ["obs_type","object"],
        ["caldat",prior_day,this_caldat]
    ]
        
}

result_limit = 1000

sia_mask_df = pd.DataFrame(requests.post(f'{adsurl}/find/?limit={result_limit}',json=jj).json()[1:])

mask_url = sia_mask_df[sia_mask_df.OBJECT.str.contains(this_filename, regex=True,na=False)]['url']
